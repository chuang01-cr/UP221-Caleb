# %% [markdown]
# # Race Profile of San Francisco
# ## Understanding the demographics of San Francisco to assess equity in access to schools
# ### By: Caleb Huang

# %%
# import pandas and geopandas for visualizations
import pandas as pd 
import geopandas as gpd

# %%
# load datafile
df = pd.read_csv('Data/SF Race Data NH.csv')

# %%
# Looking at the size (rows and columns) of the file
df.shape
# Out:
# (244, 79)

# %%
df.head()
# Out:
#      Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 0  6075010101  Census Tract 101.01, San Francisco County, Cal...         ca
# 1  6075010102  Census Tract 101.02, San Francisco County, Cal...         ca
# 2  6075010201  Census Tract 102.01, San Francisco County, Cal...         ca
# 3  6075010202  Census Tract 102.02, San Francisco County, Cal...         ca
# 4  6075010300  Census Tract 103, San Francisco County, Califo...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION  Geo_STATE  \
# 0         140            0     NaN         NaN           NaN          6
# 1         140            0     NaN         NaN           NaN          6
# 2         140            0     NaN         NaN           NaN          6
# 3         140            0     NaN         NaN           NaN          6
# 4         140            0     NaN         NaN           NaN          6
#
#    Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  \
# ...

# %%
# Loading all the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# checking my work
df.head()
# Out:
#      Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 0  6075010101  Census Tract 101.01, San Francisco County, Cal...         ca
# 1  6075010102  Census Tract 101.02, San Francisco County, Cal...         ca
# 2  6075010201  Census Tract 102.01, San Francisco County, Cal...         ca
# 3  6075010202  Census Tract 102.02, San Francisco County, Cal...         ca
# 4  6075010300  Census Tract 103, San Francisco County, Califo...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION  Geo_STATE  \
# 0         140            0     NaN         NaN           NaN          6
# 1         140            0     NaN         NaN           NaN          6
# 2         140            0     NaN         NaN           NaN          6
# 3         140            0     NaN         NaN           NaN          6
# 4         140            0     NaN         NaN           NaN          6
#
#    Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  \
# ...

# %%
# Seeing what kind of data I have
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 79 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           244 non-null    int64
#  1   Geo_QName          244 non-null    object
#  2   Geo_STUSAB         244 non-null    object
#  3   Geo_SUMLEV         244 non-null    int64
#  4   Geo_GEOCOMP        244 non-null    int64
#  5   Geo_US             0 non-null      float64
#  6   Geo_REGION         0 non-null      float64
#  7   Geo_DIVISION       0 non-null      float64
#  8   Geo_STATE          244 non-null    int64
#  9   Geo_COUNTY         244 non-null    int64
#  10  Geo_COUSUB         0 non-null      float64
#  11  Geo_PLACE          0 non-null      float64
#  12  Geo_TRACT          244 non-null    int64
#  13  Geo_BLKGRP         0 non-null      float64
#  14  Geo_CONCIT         0 non-null      float64
#  15  Geo_AIANHH         0 non-null      float64
# ...

# %%
# Converting data into string
df = pd.read_csv(
    'Data/SF Race Data NH.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
# Checking work
df.sample()
# Out:
#         Geo_FIPS                                          Geo_QName  \
# 220  06075060702  Census Tract 607.02, San Francisco County, Cal...
#
#     Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_US  Geo_REGION  Geo_DIVISION  \
# 220         ca         140            0     NaN         NaN           NaN
#
#     Geo_STATE Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_TRACT  Geo_BLKGRP  \
# 220        06        075         NaN        NaN      60702         NaN
#
#      Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  Geo_AITS  Geo_ANRC  \
# 220         NaN         NaN           NaN          NaN       NaN       NaN
#
#      Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA Geo_CNECTA  \
# 220       NaN      NaN         NaN       NaN       NaN        NaN          .
#
#     Geo_NECTADIV  Geo_UA  Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_ZCTA3  \
# 220            .     NaN         NaN       NaN       NaN        NaN
#
# ...

# %%
# Checking work
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 79 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           244 non-null    object
#  1   Geo_QName          244 non-null    object
#  2   Geo_STUSAB         244 non-null    object
#  3   Geo_SUMLEV         244 non-null    int64
#  4   Geo_GEOCOMP        244 non-null    int64
#  5   Geo_US             0 non-null      float64
#  6   Geo_REGION         0 non-null      float64
#  7   Geo_DIVISION       0 non-null      float64
#  8   Geo_STATE          244 non-null    object
#  9   Geo_COUNTY         244 non-null    object
#  10  Geo_COUSUB         0 non-null      float64
#  11  Geo_PLACE          0 non-null      float64
#  12  Geo_TRACT          244 non-null    int64
#  13  Geo_BLKGRP         0 non-null      float64
#  14  Geo_CONCIT         0 non-null      float64
#  15  Geo_AIANHH         0 non-null      float64
# ...

# %%
# shows a list of all columns that have no data
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_UA',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_PUMA5',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
# Dropping all columns with no data
df = df.dropna(axis=1,how="all")

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           244 non-null    object
#  1   Geo_QName          244 non-null    object
#  2   Geo_STUSAB         244 non-null    object
#  3   Geo_SUMLEV         244 non-null    int64
#  4   Geo_GEOCOMP        244 non-null    int64
#  5   Geo_STATE          244 non-null    object
#  6   Geo_COUNTY         244 non-null    object
#  7   Geo_TRACT          244 non-null    int64
#  8   Geo_CNECTA         244 non-null    object
#  9   Geo_NECTADIV       244 non-null    object
#  10  Geo_GEO_ID         244 non-null    object
#  11  Geo_NAME           244 non-null    object
#  12  SE_A04001_001      244 non-null    int64
#  13  SE_A04001_002      244 non-null    int64
#  14  SE_A04001_003      244 non-null    int64
#  15  SE_A04001_004      244 non-null    int64
# ...

# %%
# checking work
df.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_STUSAB  \
# 0  06075010101  Census Tract 101.01, San Francisco County, Cal...         ca
# 1  06075010102  Census Tract 101.02, San Francisco County, Cal...         ca
# 2  06075010201  Census Tract 102.01, San Francisco County, Cal...         ca
# 3  06075010202  Census Tract 102.02, San Francisco County, Cal...         ca
# 4  06075010300  Census Tract 103, San Francisco County, Califo...         ca
#
#    Geo_SUMLEV  Geo_GEOCOMP Geo_STATE Geo_COUNTY  Geo_TRACT Geo_CNECTA  \
# 0         140            0        06        075      10101          .
# 1         140            0        06        075      10102          .
# 2         140            0        06        075      10201          .
# 3         140            0        06        075      10202          .
# 4         140            0        06        075      10300          .
#
#   Geo_NECTADIV            Geo_GEO_ID             Geo_NAME  SE_A04001_001  \
# ...

# %%
total_count_columns = ['Geo_FIPS',
                       'SE_A04001_001',
                       'SE_A04001_002',
                       'SE_A04001_003',
                       'SE_A04001_004',
                       'SE_A04001_005',
                       'SE_A04001_006',
                       'SE_A04001_007',
                       'SE_A04001_008',
                       'SE_A04001_009',
                      'SE_A04001_010']

# creating a new dataframe with the desired columns
df2 = df[total_count_columns]

# %%
# showing the new df's columns in a list
columns = list(df2)
columns
# Out:
# ['Geo_FIPS',
#  'SE_A04001_001',
#  'SE_A04001_002',
#  'SE_A04001_003',
#  'SE_A04001_004',
#  'SE_A04001_005',
#  'SE_A04001_006',
#  'SE_A04001_007',
#  'SE_A04001_008',
#  'SE_A04001_009',
#  'SE_A04001_010']

# %%
# Renaming the columns
df2.columns = ['FIPS', 
'Total Pop',
'Non Hispanic',
'NH White Alone',
'NH Black Alone',
'NH American Indian Alone',
'NH Asian Alone',
'NH Native Hawaiian Alone', 
'NH Some other race Alone',
'NH Two or more races',
'Hispanic or Latino']

# %%
# checking my work
df2.sample(5)
# Out:
#             FIPS  Total Pop  Non Hispanic  NH White Alone  NH Black Alone  \
# 91   06075017903       2829          1934             838             556
# 100  06075020500       2895          2662            2112              74
# 28   06075012203       1895          1613            1075             138
# 130  06075023200       4214          2958             322            1270
# 158  06075026403       3453          2823             175              12
#
#      NH American Indian Alone  NH Asian Alone  NH Native Hawaiian Alone  \
# 91                          6             203                        23
# 100                        10             284                         0
# 28                          9             341                         0
# 130                         0            1258                         8
# 158                         0            2610                         0
#
#      NH Some other race Alone  NH Two or more races  Hispanic or Latino
# ...

# %%
# Plotting populations of Hispanic/Latino against populations of Asians
df2.plot.scatter(x='Hispanic or Latino', y='NH Asian Alone')
# Out:
# <Axes: xlabel='Hispanic or Latino', ylabel='NH Asian Alone'>

# %%
# Sorting the data from biggest to smallest
df_sorted_NH_Asian = df2.sort_values(by='NH Asian Alone',ascending = False)

# %%
# Displaying the top ten census tracts with the highest NH Asian populations
df_sorted_NH_Asian.head(10).plot.barh(x='FIPS',
                                  y='NH Asian Alone',
                                  title='Top 10 Census Tracts with Highest NH Asian Popoulation in SF in 2022')
# Out:
# <Axes: title={'center': 'Top 10 Census Tracts with Highest NH Asian Popoulation in SF in 2022'}, ylabel='FIPS'>

# %%
# finding census tracts with zero people
df2[df2['Total Pop']==0]
# Out:
#             FIPS  Total Pop  Non Hispanic  NH White Alone  NH Black Alone  \
# 238  06075980401          0             0               0               0
# 242  06075990100          0             0               0               0
# 243  06075990200          0             0               0               0
#
#      NH American Indian Alone  NH Asian Alone  NH Native Hawaiian Alone  \
# 238                         0               0                         0
# 242                         0               0                         0
# 243                         0               0                         0
#
#      NH Some other race Alone  NH Two or more races  Hispanic or Latino
# 238                         0                     0                   0
# 242                         0                     0                   0
# 243                         0                     0                   0

# %%
df_no_pop=df2[df2['Total Pop']==0]
print('There are ' + str(len(df_no_pop)) + ' census tracts with no people')
# Out:
# There are 3 census tracts with no people

# %%
# read census tracts datafile
tracts=gpd.read_file('Data/SF Census Tracts.geojson')
tracts.head()
# Out:
#       name      intptlon  awater  mtfcc      aland              namelsad  \
# 0  9805.01  -122.4193463  9769.0  G5020  1471536.0  Census Tract 9805.01
# 1   171.02  -122.4504754     0.0  G5020   294894.0   Census Tract 171.02
# 2   123.02  -122.4120970     0.0  G5020    92653.0   Census Tract 123.02
# 3   168.01  -122.4290133     0.0  G5020   226534.0   Census Tract 168.01
# 4   119.02  -122.4098067     0.0  G5020    93053.0   Census Tract 119.02
#
#   tractce statefp data_loaded_at     intptlat funcstat countyfp data_as_of  \
# 0  980501      06     2022-03-04  +37.7162081        S      075 2021-02-01
# 1  017102      06     2022-03-04  +37.7654353        S      075 2021-02-01
# 2  012302      06     2022-03-04  +37.7870222        S      075 2021-02-01
# 3  016801      06     2022-03-04  +37.7713309        S      075 2021-02-01
# 4  011902      06     2022-03-04  +37.7909959        S      075 2021-02-01
#
#          geoid                                           geometry
# ...

# %%
tracts.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
# looking at the tract's columns
tracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            244 non-null    object
#  1   intptlon        244 non-null    object
#  2   awater          244 non-null    object
#  3   mtfcc           244 non-null    object
#  4   aland           244 non-null    object
#  5   namelsad        244 non-null    object
#  6   tractce         244 non-null    object
#  7   statefp         244 non-null    object
#  8   data_loaded_at  244 non-null    datetime64[ms]
#  9   intptlat        244 non-null    object
#  10  funcstat        244 non-null    object
#  11  countyfp        244 non-null    object
#  12  data_as_of      244 non-null    datetime64[ms]
#  13  geoid           244 non-null    object
#  14  geometry        244 non-null    geometry
# dtypes: datetime64[ms](2), geometry(1), object(12)
# memory usage: 28.7+ KB

# %%
# filtering for the columns I want to see
tracts = tracts[['namelsad', 'tractce', 'geoid', 'geometry']]
tracts.head()
# Out:
#                namelsad tractce        geoid  \
# 0  Census Tract 9805.01  980501  06075980501
# 1   Census Tract 171.02  017102  06075017102
# 2   Census Tract 123.02  012302  06075012302
# 3   Census Tract 168.01  016801  06075016801
# 4   Census Tract 119.02  011902  06075011902
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...
# 1  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...
# 2  MULTIPOLYGON (((-122.415 37.78745, -122.41335 ...
# 3  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...
# 4  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...

# %%
# renaming GEOID to FIPS
tracts = tracts.rename(columns={'geoid': 'FIPS'})
tracts.head()
# Out:
#                namelsad tractce         FIPS  \
# 0  Census Tract 9805.01  980501  06075980501
# 1   Census Tract 171.02  017102  06075017102
# 2   Census Tract 123.02  012302  06075012302
# 3   Census Tract 168.01  016801  06075016801
# 4   Census Tract 119.02  011902  06075011902
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...
# 1  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...
# 2  MULTIPOLYGON (((-122.415 37.78745, -122.41335 ...
# 3  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...
# 4  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...

# %%
# creating a new dataframe so I can merge the two data sets
tracts_race = tracts.merge(df2,on="FIPS")
tracts_race.head()
# Out:
#                namelsad tractce         FIPS  \
# 0  Census Tract 9805.01  980501  06075980501
# 1   Census Tract 171.02  017102  06075017102
# 2   Census Tract 123.02  012302  06075012302
# 3   Census Tract 168.01  016801  06075016801
# 4   Census Tract 119.02  011902  06075011902
#
#                                             geometry  Total Pop  Non Hispanic  \
# 0  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...        155           155
# 1  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...       3550          3056
# 2  MULTIPOLYGON (((-122.415 37.78745, -122.41335 ...       2586          2155
# 3  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...       4013          3150
# 4  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...       2732          2361
#
#    NH White Alone  NH Black Alone  NH American Indian Alone  NH Asian Alone  \
# 0               0               0                         0             155
# ...

# %%
# plotting a map showing concentration of Asian population in San Francisco
tracts_race.plot(figsize=(12,10),
                 column='NH Asian Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# Finding all census tracts with no people again
tracts_race[tracts_race['Total Pop']==0]
# Out:
#                  namelsad tractce         FIPS  \
# 35   Census Tract 9804.01  980401  06075980401
# 88      Census Tract 9901  990100  06075990100
# 205     Census Tract 9902  990200  06075990200
#
#                                               geometry  Total Pop  \
# 35   MULTIPOLYGON (((-123.17382 37.77573, -123.1737...          0
# 88   MULTIPOLYGON (((-122.61228 37.81522, -122.5845...          0
# 205  MULTIPOLYGON (((-122.45398 37.83903, -122.4454...          0
#
#      Non Hispanic  NH White Alone  NH Black Alone  NH American Indian Alone  \
# 35              0               0               0                         0
# 88              0               0               0                         0
# 205             0               0               0                         0
#
#      NH Asian Alone  NH Native Hawaiian Alone  NH Some other race Alone  \
# 35                0                         0                         0
# ...

# %%
# deleting all census tracts with no people
tracts_race.drop([35,88,205],axis=0,inplace=True)

# %%
# plotting a new map
tracts_race.plot(figsize=(12,10),
                 column='NH Asian Alone',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <Axes: >

# %%
# Creating new columns to show percentages
tracts_race['PCT_Black'] = tracts_race['NH Black Alone']/tracts_race['Total Pop']*100
tracts_race['PCT_White'] = tracts_race['NH White Alone']/tracts_race['Total Pop']*100
tracts_race['PCT_Asian'] = tracts_race['NH Asian Alone']/tracts_race['Total Pop']*100
tracts_race['PCT_Hispanic'] = tracts_race['Hispanic or Latino']/tracts_race['Total Pop']*100

# %%
tracts_race.plot(figsize=(12,10),
                 column='PCT_Black',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >

# %%
tracts_race.plot(figsize=(12,10),
                 column='PCT_Asian',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <Axes: >

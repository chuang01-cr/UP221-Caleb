# %% [markdown]
# # Maps of SF Street Trees and Equity Priority Communities
# ## By: Caleb Huang

# %%
# import pandas
import pandas as pd 
import geopandas as gpd
import plotly.express as px

# %%
# creating the dataframe 
df = pd.read_csv('Data/Street_Tree_List.csv')

# %%
# looking at the amount of rows and columns
df.shape
# Out:
# (198393, 24)

# %%
# looking at the top 5 rows
df.head()
# Out:
#    TreeID    qLegalStatus                                        qSpecies  \
# 0  225873  DPW Maintained    Koelreuteria bipinnata :: Chinese Flame Tree
# 1  133842  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 2    3119  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 3    3120  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 4  272733  DPW Maintained     Fraxinus uhdei :: Shamel Ash: Evergreen Ash
#
#              qAddress  SiteOrder                     qSiteInfo PlantType  \
# 0      822 Alabama St        1.0  Sidewalk: Curb side : Cutout      Tree
# 1  3170 California St        1.0  Sidewalk: Curb side : Cutout      Tree
# 2  3170 California St        3.0  Sidewalk: Curb side : Cutout      Tree
# 3  3170 California St        4.0  Sidewalk: Curb side : Cutout      Tree
# 4     590 Masonic Ave        4.0  Sidewalk: Curb side : Cutout      Tree
#
#   qCaretaker qCareAssistant PlantDate   DBH   PlotSize PermitNotes  \
# 0    Private            NaN       NaN  12.0  Width 3ft         NaN
# 1    Private            NaN       NaN   8.0  Width 4ft         NaN
# 2    Private            NaN       NaN  12.0        3X3         NaN
# 3    Private            NaN       NaN   6.0        3X3         NaN
# 4    Private            NaN       NaN   NaN  Width 0ft         NaN
#
#          XCoord        YCoord   Latitude   Longitude  \
# 0  6.009091e+06  2.104279e+06  37.758462 -122.411593
# 1  5.999256e+06  2.115022e+06  37.787404 -122.446379
# 2  5.999211e+06  2.115015e+06  37.787381 -122.446532
# 3  5.999194e+06  2.115012e+06  37.787374 -122.446592
# 4  5.999164e+06  2.110904e+06  37.776091 -122.446402
#
#                                     Location  Fire Prevention Districts  \
# 0   (37.75846190721876, -122.41159276561366)                        2.0
# 1  (37.787403655494266, -122.44637901807063)                       13.0
# 2  (37.787380880159084, -122.44653244062533)                       13.0
# 3   (37.787373511112456, -122.4465917751871)                       13.0
# 4   (37.77609111946836, -122.44640232649878)                       15.0
#
#    Police Districts  Supervisor Districts  Zip Codes  Neighborhoods (old)  \
# 0               4.0                   7.0    28859.0                 19.0
# 1               6.0                   1.0    29490.0                 31.0
# 2               6.0                   1.0    29490.0                 31.0
# 3               6.0                   1.0    29490.0                 31.0
# 4               5.0                  11.0    29492.0                 16.0
#
#    Analysis Neighborhoods
# 0                    20.0
# 1                    31.0
# 2                    31.0
# 3                    31.0
# 4                    18.0

# %%
# Loading all the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# looking at all the columns
df.head()
# Out:
#    TreeID    qLegalStatus                                        qSpecies  \
# 0  225873  DPW Maintained    Koelreuteria bipinnata :: Chinese Flame Tree
# 1  133842  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 2    3119  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 3    3120  DPW Maintained  Platanus x hispanica :: Sycamore: London Plane
# 4  272733  DPW Maintained     Fraxinus uhdei :: Shamel Ash: Evergreen Ash
#
#              qAddress  SiteOrder                     qSiteInfo PlantType  \
# 0      822 Alabama St        1.0  Sidewalk: Curb side : Cutout      Tree
# 1  3170 California St        1.0  Sidewalk: Curb side : Cutout      Tree
# 2  3170 California St        3.0  Sidewalk: Curb side : Cutout      Tree
# 3  3170 California St        4.0  Sidewalk: Curb side : Cutout      Tree
# 4     590 Masonic Ave        4.0  Sidewalk: Curb side : Cutout      Tree
#
#   qCaretaker qCareAssistant PlantDate   DBH   PlotSize PermitNotes  \
# 0    Private            NaN       NaN  12.0  Width 3ft         NaN
# 1    Private            NaN       NaN   8.0  Width 4ft         NaN
# 2    Private            NaN       NaN  12.0        3X3         NaN
# 3    Private            NaN       NaN   6.0        3X3         NaN
# 4    Private            NaN       NaN   NaN  Width 0ft         NaN
#
#          XCoord        YCoord   Latitude   Longitude  \
# 0  6.009091e+06  2.104279e+06  37.758462 -122.411593
# 1  5.999256e+06  2.115022e+06  37.787404 -122.446379
# 2  5.999211e+06  2.115015e+06  37.787381 -122.446532
# 3  5.999194e+06  2.115012e+06  37.787374 -122.446592
# 4  5.999164e+06  2.110904e+06  37.776091 -122.446402
#
#                                     Location  Fire Prevention Districts  \
# 0   (37.75846190721876, -122.41159276561366)                        2.0
# 1  (37.787403655494266, -122.44637901807063)                       13.0
# 2  (37.787380880159084, -122.44653244062533)                       13.0
# 3   (37.787373511112456, -122.4465917751871)                       13.0
# 4   (37.77609111946836, -122.44640232649878)                       15.0
#
#    Police Districts  Supervisor Districts  Zip Codes  Neighborhoods (old)  \
# 0               4.0                   7.0    28859.0                 19.0
# 1               6.0                   1.0    29490.0                 31.0
# 2               6.0                   1.0    29490.0                 31.0
# 3               6.0                   1.0    29490.0                 31.0
# 4               5.0                  11.0    29492.0                 16.0
#
#    Analysis Neighborhoods
# 0                    20.0
# 1                    31.0
# 2                    31.0
# 3                    31.0
# 4                    18.0

# %%
# See details for the dataframe
df.info (verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198393 entries, 0 to 198392
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   TreeID                     198393 non-null  int64
#  1   qLegalStatus               198336 non-null  object
#  2   qSpecies                   198393 non-null  object
#  3   qAddress                   196901 non-null  object
#  4   SiteOrder                  196561 non-null  float64
#  5   qSiteInfo                  198393 non-null  object
#  6   PlantType                  198393 non-null  object
#  7   qCaretaker                 198393 non-null  object
#  8   qCareAssistant             25449 non-null   object
#  9   PlantDate                  72044 non-null   object
#  10  DBH                        153804 non-null  float64
#  11  PlotSize                   147832 non-null  object
#  12  PermitNotes                54298 non-null   object
#  13  XCoord                     195321 non-null  float64
#  14  YCoord                     195321 non-null  float64
#  15  Latitude                   195321 non-null  float64
#  16  Longitude                  195321 non-null  float64
#  17  Location                   195321 non-null  object
#  18  Fire Prevention Districts  195142 non-null  float64
#  19  Police Districts           195199 non-null  float64
#  20  Supervisor Districts       195260 non-null  float64
#  21  Zip Codes                  195254 non-null  float64
#  22  Neighborhoods (old)        195256 non-null  float64
#  23  Analysis Neighborhoods     195256 non-null  float64
# dtypes: float64(12), int64(1), object(11)
# memory usage: 36.3+ MB

# %%
# sorting out the columns I need
tree_columns = ['TreeID',
               'qSpecies',
               'qAddress',
               'PlotSize',
                'Latitude',
                'Longitude',
               'Location',
               'Analysis Neighborhoods']
# creating a new dataframe with new columns
df2 = df[tree_columns]

# %%
# Checking my work
df2.sample(1)
# Out:
#        TreeID                                           qSpecies  \
# 64449  189222  Agonis flexuosa 'After Dark' :: Peppermint wil...
#
#                    qAddress PlotSize   Latitude   Longitude  \
# 64449  101 Pennsylvania Ave      NaN  37.764178 -122.393593
#
#                                         Location  Analysis Neighborhoods
# 64449  (37.764178481086155, -122.39359341489848)                    26.0

# %%
# renaming the columns
df2.columns = ['Tree ID',
'Species',
'Tree Address',
'Plot Size',
'Latitude',
'Longitude',
'Location',
'Neighborhood']

# %%
df2.head()
# Out:
#    Tree ID                                         Species  \
# 0   225873    Koelreuteria bipinnata :: Chinese Flame Tree
# 1   133842  Platanus x hispanica :: Sycamore: London Plane
# 2     3119  Platanus x hispanica :: Sycamore: London Plane
# 3     3120  Platanus x hispanica :: Sycamore: London Plane
# 4   272733     Fraxinus uhdei :: Shamel Ash: Evergreen Ash
#
#          Tree Address  Plot Size   Latitude   Longitude  \
# 0      822 Alabama St  Width 3ft  37.758462 -122.411593
# 1  3170 California St  Width 4ft  37.787404 -122.446379
# 2  3170 California St        3X3  37.787381 -122.446532
# 3  3170 California St        3X3  37.787374 -122.446592
# 4     590 Masonic Ave  Width 0ft  37.776091 -122.446402
#
#                                     Location  Neighborhood
# 0   (37.75846190721876, -122.41159276561366)          20.0
# 1  (37.787403655494266, -122.44637901807063)          31.0
# 2  (37.787380880159084, -122.44653244062533)          31.0
# 3   (37.787373511112456, -122.4465917751871)          31.0
# 4   (37.77609111946836, -122.44640232649878)          18.0

# %%
# counting the amount of trees in each neighborhood
df2['Neighborhood'].value_counts()
# Out:
# Neighborhood
# 20.0    16175
# 41.0    15569
# 1.0     13599
# 35.0    12552
# 22.0     9055
# 2.0      8908
# 5.0      8055
# 29.0     6915
# 30.0     6604
# 8.0      6540
# 14.0     6451
# 39.0     6063
# 9.0      5726
# 26.0     5700
# 3.0      5375
# 34.0     5159
# 7.0      4899
# 13.0     4821
# 24.0     4257
# 10.0     3908
# 31.0     3776
# 11.0     3775
# 28.0     3748
# 18.0     3304
# 23.0     3192
# 32.0     3188
# 4.0      2905
# 21.0     2683
# 25.0     2622
# 36.0     2429
# 33.0     1477
# 40.0     1439
# 15.0     1249
# 6.0      1039
# 16.0      935
# 38.0      726
# 19.0      200
# 27.0      111
# 12.0       97
# 17.0       22
# 37.0        8
# Name: count, dtype: int64

# %%
# creating a variable for tree count
neighborhood_tree_count = df2['Neighborhood'].value_counts()

# %%
# converting series into a dataframe
neighborhood_tree_count = neighborhood_tree_count.reset_index()
neighborhood_tree_count
# Out:
#     Neighborhood  count
# 0           20.0  16175
# 1           41.0  15569
# 2            1.0  13599
# 3           35.0  12552
# 4           22.0   9055
# 5            2.0   8908
# 6            5.0   8055
# 7           29.0   6915
# 8           30.0   6604
# 9            8.0   6540
# 10          14.0   6451
# 11          39.0   6063
# 12           9.0   5726
# 13          26.0   5700
# 14           3.0   5375
# 15          34.0   5159
# 16           7.0   4899
# 17          13.0   4821
# 18          24.0   4257
# 19          10.0   3908
# 20          31.0   3776
# 21          11.0   3775
# 22          28.0   3748
# 23          18.0   3304
# 24          23.0   3192
# 25          32.0   3188
# 26           4.0   2905
# 27          21.0   2683
# 28          25.0   2622
# 29          36.0   2429
# 30          33.0   1477
# 31          40.0   1439
# 32          15.0   1249
# 33           6.0   1039
# 34          16.0    935
# 35          38.0    726
# 36          19.0    200
# 37          27.0    111
# 38          12.0     97
# 39          17.0     22
# 40          37.0      8

# %%
# renaming columns
neighborhood_tree_count.columns = ['Neighborhood', 'Tree Count']
neighborhood_tree_count
# Out:
#     Neighborhood  Tree Count
# 0           20.0       16175
# 1           41.0       15569
# 2            1.0       13599
# 3           35.0       12552
# 4           22.0        9055
# 5            2.0        8908
# 6            5.0        8055
# 7           29.0        6915
# 8           30.0        6604
# 9            8.0        6540
# 10          14.0        6451
# 11          39.0        6063
# 12           9.0        5726
# 13          26.0        5700
# 14           3.0        5375
# 15          34.0        5159
# 16           7.0        4899
# 17          13.0        4821
# 18          24.0        4257
# 19          10.0        3908
# 20          31.0        3776
# 21          11.0        3775
# 22          28.0        3748
# 23          18.0        3304
# 24          23.0        3192
# 25          32.0        3188
# 26           4.0        2905
# 27          21.0        2683
# 28          25.0        2622
# 29          36.0        2429
# 30          33.0        1477
# 31          40.0        1439
# 32          15.0        1249
# 33           6.0        1039
# 34          16.0         935
# 35          38.0         726
# 36          19.0         200
# 37          27.0         111
# 38          12.0          97
# 39          17.0          22
# 40          37.0           8

# %%
# showing neighborhood tree count on a bar graph
neighborhood_tree_count.plot.bar(x = 'Neighborhood', y = 'Tree Count', title = 'Number of Trees in Neighborhoods')
# Out:
# <Axes: title={'center': 'Number of Trees in Neighborhoods'}, xlabel='Neighborhood'>

# %%
sf_epcs=gpd.read_file("Data/SF EPCs/SF_EPCs_2021.shp")
sf_epcs.head()
# Out:
#          geoid state_fip county_fip   tract block_grou  tot_pop  pop_minori  \
# 0  06075010700        06        075  010700         NA     5522        4792
# 1  06075012401        06        075  012401         NA     4782        3424
# 2  06075010600        06        075  010600         NA     3356        2107
# 3  06075011300        06        075  011300         NA     3046        2585
# 4  06075011800        06        075  011800         NA     1477        1338
#
#    pct_minori  tot_pop_se  pop_over75  pct_over75  tot_fam  pop_spfam  \
# 0    0.867802        5522         871    0.157733     1378        121
# 1    0.716018        4782         166    0.034714      725        110
# 2    0.627831        3356         425    0.126639      673         34
# 3    0.848654        3046         737    0.241957      675         83
# 4    0.905890        1477         250    0.169262      370         37
#
#    pct_spfam  tot_pop_ov  pop_lep   pct_lep  tot_pop_po  pop_below2  \
# 0   0.087808      5370.0   3078.0  0.573184        5522        3170
# 1   0.151724      4521.0    785.0  0.173634        4782        2284
# 2   0.050520      3335.0   1012.0  0.303448        3356        1388
# 3   0.122963      2927.0   1429.0  0.488213        3010        1434
# 4   0.100000      1426.0    710.0  0.497896        1477         780
#
#    pct_below2  tot_pop_ci  pop_disabi  pct_disab  tot_hh  pop_zvhhs  \
# 0    0.574067      5522.0       788.0   0.142702  2491.0     1829.0
# 1    0.477624      4782.0      1021.0   0.213509  2749.0     2138.0
# 2    0.413588      3343.0       488.0   0.145977  1797.0     1248.0
# 3    0.476412      3046.0       745.0   0.244583  1546.0     1188.0
# 4    0.528097      1477.0       204.0   0.138118   735.0      605.0
#
#    pct_zvhhs  pop_hus_re  pct_hus_re  \
# 0   0.734243         527    0.211562
# 1   0.777737         878    0.319389
# 2   0.694491         264    0.146912
# 3   0.768435         332    0.214748
# 4   0.823129         173    0.235374
#
#                                             geometry
# 0  POLYGON ((-122.41291 37.80218, -122.41138 37.8...
# 1  POLYGON ((-122.41771 37.78424, -122.41607 37.7...
# 2  POLYGON ((-122.41102 37.80117, -122.40777 37.8...
# 3  POLYGON ((-122.41172 37.79629, -122.40843 37.7...
# 4  POLYGON ((-122.4079 37.79406, -122.4048 37.794...

# %%
sf_epcs.plot()
# Out:
# <Axes: >

# %%
gdf = gpd.GeoDataFrame(
    df2, geometry=gpd.points_from_xy(df2.Longitude, df2.Latitude),crs=4326)

# %%
# creating a spatial join
trees_per_tract = gpd.sjoin(sf_epcs, gdf)

# %%
# creating a count per EPC tract
tree_counts = trees_per_tract.value_counts('tract').reset_index(name='tree count')
tree_counts
# Out:
#      tract  tree count
# 0   023102        2137
# 1   010100        1802
# 2   017802        1575
# 3   020100        1573
# 4   017601        1509
# 5   016100        1507
# 6   015801        1506
# 7   061200        1331
# 8   023200        1263
# 9   015500        1248
# 10  023103        1215
# 11  015900         988
# 12  031400         976
# 13  022901         974
# 14  010500         967
# 15  012402         967
# 16  020900         885
# 17  023400         875
# 18  023300         866
# 19  026200         839
# 20  031301         828
# 21  011700         799
# 22  016000         726
# 23  026001         633
# 24  023001         628
# 25  042700         621
# 26  022902         620
# 27  025702         598
# 28  017801         597
# 29  022801         542
# 30  026301         475
# 31  061100         453
# 32  031202         434
# 33  020200         429
# 34  016300         423
# 35  010600         399
# 36  012501         392
# 37  026403         381
# 38  012000         369
# 39  020800         327
# 40  012202         326
# 41  033204         308
# 42  031201         307
# 43  010700         300
# 44  026402         259
# 45  980600         259
# 46  023003         251
# 47  011100         239
# 48  031302         213
# 49  012201         210
# 50  980501         202
# 51  026404         195
# 52  025500         186
# 53  060502         185
# 54  012401         182
# 55  042601         176
# 56  011300         157
# 57  012302         130
# 58  012301         121
# 59  026401         115
# 60  012502         112
# 61  026100         112
# 62  011800         105
# 63  033201          98
# 64  017902           8

# %%
df_least_trees=tree_counts.sort_values(by='tree count',ascending = True)
df_least_trees
# Out:
#      tract  tree count
# 64  017902           8
# 63  033201          98
# 62  011800         105
# 61  026100         112
# 60  012502         112
# 59  026401         115
# 58  012301         121
# 57  012302         130
# 56  011300         157
# 55  042601         176
# 54  012401         182
# 53  060502         185
# 52  025500         186
# 51  026404         195
# 50  980501         202
# 49  012201         210
# 48  031302         213
# 47  011100         239
# 46  023003         251
# 45  980600         259
# 44  026402         259
# 43  010700         300
# 42  031201         307
# 41  033204         308
# 40  012202         326
# 39  020800         327
# 38  012000         369
# 37  026403         381
# 36  012501         392
# 35  010600         399
# 34  016300         423
# 33  020200         429
# 32  031202         434
# 31  061100         453
# 30  026301         475
# 29  022801         542
# 28  017801         597
# 27  025702         598
# 26  022902         620
# 25  042700         621
# 24  023001         628
# 23  026001         633
# 22  016000         726
# 21  011700         799
# 20  031301         828
# 19  026200         839
# 18  023300         866
# 17  023400         875
# 16  020900         885
# 15  012402         967
# 14  010500         967
# 13  022901         974
# 12  031400         976
# 11  015900         988
# 10  023103        1215
# 9   015500        1248
# 8   023200        1263
# 7   061200        1331
# 6   015801        1506
# 5   016100        1507
# 4   017601        1509
# 3   020100        1573
# 2   017802        1575
# 1   010100        1802
# 0   023102        2137

# %%
# creating a bar chart showing the tracts with the least amount of trees
df_least_trees.head(10).plot.barh(x='tract',
                                  y='tree count',
                                  title='Census Tracts with the Least Number of Trees')
# Out:
# <Axes: title={'center': 'Census Tracts with the Least Number of Trees'}, ylabel='tract'>

# %%
ten_least_trees=df_least_trees.head(10)
ten_least_trees
# Out:
#      tract  tree count
# 64  017902           8
# 63  033201          98
# 62  011800         105
# 61  026100         112
# 60  012502         112
# 59  026401         115
# 58  012301         121
# 57  012302         130
# 56  011300         157
# 55  042601         176

# %%
# merging trees to EPC neighborhood
neighborhoodtrees = sf_epcs.merge(tree_counts, how='left',on='tract')

# %%
# checking my work
neighborhoodtrees.sample()
# Out:
#            geoid state_fip county_fip   tract block_grou  tot_pop  pop_minori  \
# 58  060750264011        06        075  026401          1     1886        1859
#
#     pct_minori  tot_pop_se  pop_over75  pct_over75  tot_fam  pop_spfam  \
# 58    0.985684        1886         213    0.112937      402        101
#
#     pct_spfam  tot_pop_ov  pop_lep   pct_lep  tot_pop_po  pop_below2  \
# 58   0.251244         0.0      0.0  0.277694        1873         581
#
#     pct_below2  tot_pop_ci  pop_disabi  pct_disab  tot_hh  pop_zvhhs  \
# 58    0.310198         0.0         0.0   0.082582     0.0        0.0
#
#     pct_zvhhs  pop_hus_re  pct_hus_re  \
# 58   0.164506           0    0.078764
#
#                                              geometry  tree count
# 58  POLYGON ((-122.41621 37.71453, -122.41616 37.7...         115

# %%
import matplotlib.pyplot as plt

# %%
# plot trees per Equity Priority Community
fig,ax = plt.subplots(figsize=(12,12))

neighborhoodtrees.plot(ax=ax,column='tree count',legend=True,cmap='Reds')

ax.axis('off')

# add title
ax.set_title('Trees by EPC Neighborhood in SF')
# Out:
# Text(0.5, 1.0, 'Trees by EPC Neighborhood in SF')

# %%
# reading the datafile I need
sf_census=gpd.read_file("Data/SF Census Tracts.geojson")

# %%
# plotting the census tracts
sf_census.plot()
# Out:
# <Axes: >

# %%
# deleting all census tracts with no people
sf_census.drop([35,88,205],axis=0,inplace=True)

# %%
# plotting again to check my work
sf_census.plot()
# Out:
# <Axes: >

# %%
# creating a new variable where my geodata frame and census tracts are joined
trees_per_census_tract = gpd.sjoin(sf_census, gdf)

# %%
# creating a count of trees per census tract
tree_counts1 = trees_per_census_tract.value_counts('tractce').reset_index(name='tree count')
tree_counts1
# Out:
#     tractce  tree count
# 0    030900        3724
# 1    980900        3303
# 2    030800        2803
# 3    031100        2645
# 4    025200        2503
# 5    022801        2354
# 6    013300        2261
# 7    030400        2230
# 8    013200        2204
# 9    021800        2157
# 10   017700        2090
# 11   023102        2087
# 12   010500        1877
# 13   025300        1847
# 14   021700        1793
# 15   021500        1747
# 16   022600        1718
# 17   030700        1718
# 18   021100        1689
# 19   035300        1606
# 20   021600        1574
# 21   032700        1542
# 22   022704        1530
# 23   015801        1511
# 24   018000        1501
# 25   042800        1487
# 26   010101        1483
# 27   030301        1480
# 28   025100        1461
# 29   021200        1456
# 30   031000        1449
# 31   060701        1406
# 32   017000        1379
# 33   021400        1364
# 34   016802        1363
# 35   061200        1362
# 36   016700        1348
# 37   017101        1348
# 38   025401        1324
# 39   021000        1295
# 40   017102        1287
# 41   023103        1285
# 42   016900        1281
# 43   016200        1262
# 44   023200        1262
# 45   015500        1239
# 46   030101        1238
# 47   016300        1226
# 48   061000        1213
# 49   022803        1168
# 50   025402        1168
# 51   021300        1127
# 52   026100        1115
# 53   020101        1108
# 54   020602        1101
# 55   020401        1092
# 56   020601        1092
# 57   020300        1086
# 58   030102        1082
# 59   017804        1076
# 60   016801        1047
# 61   031201        1042
# 62   030202        1040
# 63   020500        1035
# 64   016500        1035
# 65   047600        1031
# 66   015900         997
# 67   025502         992
# 68   031302         988
# 69   025900         984
# 70   060702         984
# 71   033001         977
# 72   022901         974
# 73   032901         967
# 74   040200         964
# 75   030600         961
# 76   016102         952
# 77   033002         947
# 78   030302         934
# 79   061507         930
# 80   022903         924
# 81   035102         919
# 82   016601         915
# 83   025600         914
# 84   020701         903
# 85   023300         896
# 86   020900         885
# 87   061401         885
# 88   012801         877
# 89   023400         861
# 90   045100         857
# 91   015701         857
# 92   012700         856
# 93   022702         850
# 94   061501         833
# 95   031301         828
# 96   015702         822
# 97   011700         820
# 98   016400         815
# 99   040100         810
# 100  015401         804
# 101  025501         804
# 102  015202         800
# 103  020202         795
# 104  012405         783
# 105  015100         774
# 106  045201         757
# 107  047903         748
# 108  015300         746
# 109  010300         745
# 110  016000         725
# 111  047902         719
# 112  032902         715
# 113  025403         709
# 114  020801         702
# 115  030201         700
# 116  015402         687
# 117  061402         685
# 118  026002         684
# 119  012602         677
# 120  025701         674
# 121  035400         663
# 122  017603         654
# 123  010202         653
# 124  061503         650
# 125  026004         637
# 126  026001         636
# 127  047801         635
# 128  010201         631
# 129  042700         629
# 130  010402         626
# 131  013500         620
# 132  026302         620
# 133  022902         620
# 134  015600         614
# 135  042602         608
# 136  031402         605
# 137  032801         599
# 138  025702         598
# 139  017801         597
# 140  013402         594
# 141  023001         593
# 142  011200         590
# 143  017602         585
# 144  047701         579
# 145  035101         577
# 146  026003         562
# 147  016101         555
# 148  047802         555
# 149  032602         553
# 150  012902         552
# 151  023003         538
# 152  047702         535
# 153  010800         529
# 154  032802         527
# 155  035202         524
# 156  060703         523
# 157  015802         515
# 158  017803         499
# 159  020702         499
# 160  020802         497
# 161  022802         495
# 162  061502         487
# 163  026202         486
# 164  033100         479
# 165  016602         477
# 166  012802         474
# 167  061508         472
# 168  035201         471
# 169  032601         463
# 170  013102         462
# 171  013002         462
# 172  061101         461
# 173  042601         460
# 174  026301         457
# 175  020402         450
# 176  020201         435
# 177  031202         435
# 178  013401         434
# 179  033203         431
# 180  020102         428
# 181  047904         423
# 182  025800         423
# 183  013001         423
# 184  026402         419
# 185  011102         411
# 186  010600         400
# 187  026303         390
# 188  045202         387
# 189  026403         382
# 190  013101         368
# 191  031401         366
# 192  015201         364
# 193  012202         360
# 194  010401         351
# 195  026201         351
# 196  010102         332
# 197  010902         332
# 198  010901         327
# 199  061506         306
# 200  012503         287
# 201  012601         280
# 202  030500         275
# 203  011002         271
# 204  033204         264
# 205  017604         261
# 206  980600         254
# 207  011001         246
# 208  011101         243
# 209  026401         238
# 210  060502         232
# 211  012901         216
# 212  011902         215
# 213  012001         201
# 214  026404         185
# 215  012406         184
# 216  012100         183
# 217  012002         173
# 218  011300         157
# 219  060400         153
# 220  010702         151
# 221  012204         150
# 222  010701         149
# 223  011901         146
# 224  012302         130
# 225  012301         121
# 226  012502         112
# 227  060100         108
# 228  011800         105
# 229  980501         104
# 230  012404          96
# 231  980300          91
# 232  012504          89
# 233  012403          86
# 234  033201          83
# 235  061505          81
# 236  061504          72
# 237  012203          60
# 238  061102          16
# 239  017903           8
# 240  980200           6

# %%
# creating a merge where I am merging census tracts to their tree counts
neighborhoodtrees1 = sf_census.merge(tree_counts1, how='left',on='tractce')

# %%
least_trees=neighborhoodtrees1.sort_values(by='tree count',ascending = True)
ten_least_trees=least_trees.head(10)

# %%
ten_least_trees.plot(figsize=(12,12))
# Out:
# <Axes: >

# %%
# checking my work
neighborhoodtrees1.sample()
# Out:
#    name      intptlon awater  mtfcc     aland          namelsad tractce  \
# 73  113  -122.4093492    0.0  G5020  102298.0  Census Tract 113  011300
#
#    statefp data_loaded_at     intptlat funcstat countyfp data_as_of  \
# 73      06     2022-03-04  +37.7946971        S      075 2021-02-01
#
#           geoid                                           geometry  tree count
# 73  06075011300  MULTIPOLYGON (((-122.41172 37.79629, -122.4108...         157

# %%
# plot trees per Equity Priority Community
fig,ax = plt.subplots(figsize=(12,12))

neighborhoodtrees1.plot(ax=ax,column='tree count',legend=True,cmap='Reds')

ax.axis('off')

# add title
ax.set_title('Street Trees by Census Tract in SF')
# Out:
# Text(0.5, 1.0, 'Street Trees by Census Tract in SF')

# %%
from shapely.geometry import Polygon

# %%
# plotting both the Equity Priority Communities and Census tracts map
sf_epcs.plot()
neighborhoodtrees1.plot()
# Out:
# <Axes: >

# %%
# overlaying the Equity Priority Communities Map over the Street Trees Map
res_identity=sf_epcs.overlay(neighborhoodtrees1, how='identity')

ax = res_identity.plot(figsize=(12,10),
                       cmap='tab10')

neighborhoodtrees1.plot(ax=ax,column='tree count',legend=True,cmap='Reds');

sf_epcs.plot(figsize=(12,10),
             ax=ax, facecolor='none', edgecolor='k', linewidth=.5);

# add title
ax.set_title('Street Trees by Census Tract in SF')
ax.axis('off')
plt.savefig('Street Trees.png')
# Out:
# /opt/conda/lib/python3.11/site-packages/geopandas/geodataframe.py:2675: UserWarning: `keep_geom_type=True` in overlay resulted in 33 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   return geopandas.overlay(
